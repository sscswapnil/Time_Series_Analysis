# %%
import pandas as pd
import numpy as np
# %matplotlib inline
import matplotlib.pyplot as plt

# %%
df = pd.read_csv(r'F:\DS\Time_Series_Analysis\[ FreeCourseWeb.com ] Udemy - Python for Time Series Data Analysis\01. Introduction\UDEMY_TSA_FINAL\Data\Alcohol_Sales.csv',index_col='DATE',parse_dates=True)
df.index.freq = 'MS'

# %%
df.head()
# Out:
#             S4248SM144NCEN
# DATE
# 1992-01-01            3459
# 1992-02-01            3458
# 1992-03-01            4002
# 1992-04-01            4564
# 1992-05-01            4221

# %%
df.columns = ['Sales']

# %%
df.plot(figsize=(12,8))

# %%
from statsmodels.tsa.seasonal import seasonal_decompose

# %%
results = seasonal_decompose(df['Sales'])
results.observed.plot(figsize=(12,2))

# %%
results.trend.plot(figsize=(12,2))

# %%
results.seasonal.plot(figsize=(12,2))

# %%
results.resid.plot(figsize=(12,2))

# %% [markdown]
# ## Train_Test_Split

# %%
len(df)
# Out:
# 325

# %%
325-12
# Out:
# 313

# %%
train = df.iloc[:313]
test = df.iloc[313:]

# %%
len(test)
# Out:
# 12

# %% [markdown]
# ## Scale Data

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
scaler = MinMaxScaler()

# %%
# IGNORE WARNING ITS JUST CONVERTING TO FLOATS
# WE ONLY FIT TO TRAININ DATA, OTHERWISE WE ARE CHEATING ASSUMING INFO ABOUT TEST SET
scaler.fit(train)
# Out:
# MinMaxScaler(copy=True, feature_range=(0, 1))

# %%
scaled_train = scaler.transform(train)
scaled_test = scaler.transform(test)

# %% [markdown]
# ## Time_Series_Generator

# %%
from keras.preprocessing.sequence import TimeseriesGenerator
# Out:
# Using TensorFlow backend.

# %%
scaled_train
# Out:
# array([[0.03658432],
#        [0.03649885],
#        [0.08299855],
#        [0.13103684],
#        [0.1017181 ],
#        [0.12804513],
#        [0.12266006],
#        [0.09453799],
#        [0.09359774],
#        [0.10496624],
#        [0.10334217],
#        [0.16283443],
#        [0.        ],
#        [0.0196598 ],
#        [0.09650397],
#        [0.11505257],
#        [0.10906915],
#        [0.14231986],
#        [0.12197624],
#        [0.12189076],
#        [0.11394136],
#        [0.10300026],
#        [0.12556629],
#        [0.16608257],
#        [0.00376101],
#        [0.02957518],
#        [0.12069408],
#        [0.10513719],
#        [0.12214719],
#        [0.16702282],
#        [0.11052227],
#        [0.14428584],
#        [0.11479614],
#        [0.10402599],
#        [0.14984187],
#        [0.16582614],
#        [0.02897684],
#        [0.03872126],
#        [0.10582101],
#        [0.08231473],
#        [0.14394393],
#        [0.16608257],
#        [0.10188905],
#        [0.16830498],
#        [0.10291478],
#        [0.13018207],
#        [0.15556885],
#        [0.15343192],
#        [0.0570989 ],
#        [0.08137448],
#        [0.10522267],
#        [0.1357381 ],
#        [0.18702453],
#        [0.15428669],
#        [0.16326182],
#        [0.17360458],
#        [0.11402684],
#        [0.16933071],
#        [0.15548337],
#        [0.17659629],
#        [0.06214206],
#        [0.06786905],
#        [0.12163433],
#        [0.13710574],
#        [0.18625524],
#        [0.17317719],
#        [0.18805026],
#        [0.17121121],
#        [0.16574066],
#        [0.19753825],
#        [0.1538593 ],
#        [0.25079067],
#        [0.0653902 ],
#        [0.08445166],
#        [0.15958629],
#        [0.17599795],
#        [0.18856313],
#        [0.20651338],
#        [0.20548765],
#        [0.17745106],
#        [0.21232584],
#        [0.2181383 ],
#        [0.19788016],
#        [0.27822891],
#        [0.72006154],
#        [0.3307975 ],
#        [0.42593384],
#        [0.58133174],
#        [0.5342337 ],
#        [0.59287119],
#        [0.71057355],
#        [0.51927515],
#        [0.63578084],
#        [0.60295752],
#        [0.56252671],
#        [0.62372852],
#        [0.72245491],
#        [0.38080178],
#        [0.47952816],
#        [0.57081802],
#        [0.54637148],
#        [0.7104026 ],
#        [0.70459014],
#        [0.58244294],
#        [0.69510215],
#        [0.55568852],
#        [0.66014189],
#        [0.67715189],
#        [0.75997949],
#        [0.45850073],
#        [0.50064108],
#        [0.60509445],
#        [0.63783229],
#        [0.78528079],
#        [0.71407813],
#        [0.69706813],
#        [0.72065989],
#        [0.63791777],
#        [0.72732712],
#        [0.69296521],
#        [0.82725019],
#        [0.47234806],
#        [0.51525771],
#        [0.6003932 ],
#        [0.67920335],
#        [0.74886742],
#        [0.75844089],
#        [0.67817762],
#        [0.67954526],
#        [0.66646722],
#        [0.75100436],
#        [0.63586631],
#        [0.8786221 ],
#        [0.45892811],
#        [0.51551415],
#        [0.65740662],
#        [0.69031541],
#        [0.72459185],
#        [0.84391828],
#        [0.75544918],
#        [0.70031627],
#        [0.76852722],
#        [0.76519361],
#        [0.72442089],
#        [0.95324387],
#        [0.48012651],
#        [0.62313018],
#        [0.7757928 ],
#        [0.71706984],
#        [0.78699034],
#        [0.91033422],
#        [0.67689546],
#        [0.8264809 ],
#        [0.78989657],
#        [0.75852637],
#        [0.85349175],
#        [0.97358749],
#        [0.51389008],
#        [0.63432772],
#        [0.80776135],
#        [0.72313873],
#        [0.89870929],
#        [1.        ],
#        [0.71672793],
#        [0.88648602],
#        [0.75869732],
#        [0.82742115],
#        [0.87443371],
#        [0.96025301],
#        [0.5584238 ]])

# %%
# define generator
n_input = 2
n_features = 1
generator = TimeseriesGenerator(scaled_train, scaled_train, length=n_input, batch_size=1)

# %%
len(scaled_train)
# Out:
# 313

# %%
len(generator) # n_input = 2
# Out:
# 311

# %%
scaled_train
# Out:
# array([[0.03658432],
#        [0.03649885],
#        [0.08299855],
#        [0.13103684],
#        [0.1017181 ],
#        [0.12804513],
#        [0.12266006],
#        [0.09453799],
#        [0.09359774],
#        [0.10496624],
#        [0.10334217],
#        [0.16283443],
#        [0.        ],
#        [0.0196598 ],
#        [0.09650397],
#        [0.11505257],
#        [0.10906915],
#        [0.14231986],
#        [0.12197624],
#        [0.12189076],
#        [0.11394136],
#        [0.10300026],
#        [0.12556629],
#        [0.16608257],
#        [0.00376101],
#        [0.02957518],
#        [0.12069408],
#        [0.10513719],
#        [0.12214719],
#        [0.16702282],
#        [0.11052227],
#        [0.14428584],
#        [0.11479614],
#        [0.10402599],
#        [0.14984187],
#        [0.16582614],
#        [0.02897684],
#        [0.03872126],
#        [0.10582101],
#        [0.08231473],
#        [0.14394393],
#        [0.16608257],
#        [0.10188905],
#        [0.16830498],
#        [0.10291478],
#        [0.13018207],
#        [0.15556885],
#        [0.15343192],
#        [0.0570989 ],
#        [0.08137448],
#        [0.4559364 ],
#        [0.50123942],
#        [0.5780836 ],
#        [0.59372596],
#        [0.55748355],
#        [0.54226857],
#        [0.52944696],
#        [0.59124712],
#        [0.48952902],
#        [0.66740747],
#        [0.36199675],
#        [0.3886657 ],
#        [0.4835456 ],
#        [0.52406189],
#        [0.54175571],
#        [0.60996666],
#        [0.55355159],
#        [0.50363279],
#        [0.5334644 ],
#        [0.51662535],
#        [0.5058552 ],
#        [0.66774938],
#        [0.30147876],
#        [0.38037439],
#        [0.55081631],
#        [0.54645696],
#        [0.54021711],
#        [0.64287546],
#        [0.51679631],
#        [0.53354988],
#        [0.54611505],
#        [0.54551671],
#        [0.58423797],
#        [0.72006154],
#        [0.3307975 ],
#        [0.42593384],
#        [0.58133174],
#        [0.5342337 ],
#        [0.59287119],
#        [0.71057355],
#        [0.51927515],
#        [0.63578084],
#        [0.60295752],
#        [0.56252671],
#        [0.62372852],
#        [0.72245491],
#        [0.38080178],
#        [0.47952816],
#        [0.57081802],
#        [0.54637148],
#        [0.7104026 ],
#        [0.70459014],
#        [0.58244294],
#        [0.69510215],
#        [0.55568852],
#        [0.66014189],
#        [0.67715189],
#        [0.75997949],
#        [0.45850073],
#        [0.50064108],
#        [0.60509445],
#        [0.63783229],
#        [0.78528079],
#        [0.71407813],
#        [0.69706813],
#        [0.72065989],
#        [0.63791777],
#        [0.72732712],
#        [0.69296521],
#        [0.82725019],
#        [0.47234806],
#        [0.51525771],
#        [0.6003932 ],
#        [0.67920335],
#        [0.74886742],
#        [0.75844089],
#        [0.67817762],
#        [0.67954526],
#        [0.66646722],
#        [0.75100436],
#        [0.63586631],
#        [0.8786221 ],
#        [0.45892811],
#        [0.51551415],
#        [0.65740662],
#        [0.69031541],
#        [0.72459185],
#        [0.84391828],
#        [0.75544918],
#        [0.70031627],
#        [0.76852722],
#        [0.76519361],
#        [0.72442089],
#        [0.95324387],
#        [0.48012651],
#        [0.62313018],
#        [0.7757928 ],
#        [0.71706984],
#        [0.78699034],
#        [0.91033422],
#        [0.67689546],
#        [0.8264809 ],
#        [0.78989657],
#        [0.75852637],
#        [0.85349175],
#        [0.97358749],
#        [0.51389008],
#        [0.63432772],
#        [0.80776135],
#        [0.72313873],
#        [0.89870929],
#        [1.        ],
#        [0.71672793],
#        [0.88648602],
#        [0.75869732],
#        [0.82742115],
#        [0.87443371],
#        [0.96025301],
#        [0.5584238 ]])

# %%
# What does the first batch look like?
X,y = generator[0]

# %%
print(f'Given the Array: \n{X.flatten()}')
print(f'Predict this y: \n {y}')
# Out:
# Given the Array:
# [0.03658432 0.03649885]
# Predict this y:
#  [[0.08299855]]

# %%
# Let's redefine to get 12 months back and then predict the next month out
n_input = 12
generator = TimeseriesGenerator(scaled_train, scaled_train, length=n_input, batch_size=1)

# %%
# What does the first batch look like?
X,y = generator[0]

# %%
print(f'Given the Array: \n{X.flatten()}')
print(f'Predict this y: \n {y}')
# Out:
# Given the Array:
# [0.03658432 0.03649885 0.08299855 0.13103684 0.1017181  0.12804513
#  0.12266006 0.09453799 0.09359774 0.10496624 0.10334217 0.16283443]
# Predict this y:
#  [[0.]]

# %% [markdown]
# ## Creat_The_Model

# %%
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM

# %%
# define model
model = Sequential()
model.add(LSTM(100, activation='relu', input_shape=(n_input, n_features)))
model.add(Dense(1))
model.compile(optimizer='adam', loss='mse')

# %%
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_1 (LSTM)                (None, 100)               40800
# _________________________________________________________________
# dense_1 (Dense)              (None, 1)                 101
# =================================================================
# Total params: 40,901
# Trainable params: 40,901
# Non-trainable params: 0
# _________________________________________________________________

# %%
# fit model
model.fit_generator(generator,epochs=50)
# Out:
# Epoch 1/50
# 301/301 [==============================] - 7s 24ms/step - loss: 0.0197
# Epoch 2/50
# 301/301 [==============================] - 3s 9ms/step - loss: 0.0104
# Epoch 3/50
# 301/301 [==============================] - 4s 15ms/step - loss: 0.0080
# Epoch 4/50
# 301/301 [==============================] - 4s 13ms/step - loss: 0.0083
# Epoch 5/50
# 301/301 [==============================] - 2s 8ms/step - loss: 0.0081
# Epoch 6/50
# 301/301 [==============================] - 2s 8ms/step - loss: 0.0061
# Epoch 7/50
# 301/301 [==============================] - 2s 7ms/step - loss: 0.0044
# Epoch 8/50
# 301/301 [==============================] - 2s 8ms/step - loss: 0.0045
# Epoch 9/50
# 301/301 [==============================] - 2s 7ms/step - loss: 0.0036
# Epoch 10/50
# 301/301 [==============================] - 2s 7ms/step - loss: 0.0029
# Epoch 11/50
# 301/301 [==============================] - 2s 8ms/step - loss: 0.0028
# Epoch 12/50
# 301/301 [==============================] - 2s 8ms/step - loss: 0.0025
# Epoch 13/50
# 301/301 [==============================] - 2s 7ms/step - loss: 0.0018
# Epoch 14/50
# 301/301 [==============================] - 2s 7ms/step - loss: 0.0022
# Epoch 15/50
# 301/301 [==============================] - 2s 8ms/step - loss: 0.0022
# Epoch 16/50
# 301/301 [==============================] - 2s 8ms/step - loss: 0.0018
# Epoch 17/50
# 301/301 [==============================] - 3s 8ms/step - loss: 0.0018
# Epoch 18/50
# 301/301 [==============================] - 2s 7ms/step - loss: 0.0019
# Epoch 19/50
# 301/301 [==============================] - 2s 7ms/step - loss: 0.0019
# Epoch 20/50
# 301/301 [==============================] - 2s 6ms/step - loss: 0.0015
# Epoch 21/50
# 301/301 [==============================] - 2s 7ms/step - loss: 0.0015
# Epoch 22/50
# 301/301 [==============================] - 2s 7ms/step - loss: 0.0015
# Epoch 23/50
# 301/301 [==============================] - 2s 6ms/step - loss: 0.0016
# Epoch 24/50
# 301/301 [==============================] - 2s 6ms/step - loss: 0.0015
# Epoch 25/50
# 301/301 [==============================] - 2s 6ms/step - loss: 0.0017
# Epoch 26/50
# 301/301 [==============================] - 2s 5ms/step - loss: 0.0017
# Epoch 27/50
# 301/301 [==============================] - 2s 6ms/step - loss: 0.0016
# Epoch 28/50
# 301/301 [==============================] - 2s 6ms/step - loss: 0.0017
# Epoch 29/50
# 301/301 [==============================] - 4s 15ms/step - loss: 0.0014
# Epoch 30/50
# 301/301 [==============================] - 4s 14ms/step - loss: 0.0015
# Epoch 31/50
# 301/301 [==============================] - 3s 11ms/step - loss: 0.0015
# Epoch 32/50
# 301/301 [==============================] - 2s 8ms/step - loss: 0.0014
# Epoch 33/50
# 301/301 [==============================] - 2s 8ms/step - loss: 0.0016
# Epoch 34/50
# 301/301 [==============================] - 2s 8ms/step - loss: 0.0015
# Epoch 35/50
# 301/301 [==============================] - 2s 6ms/step - loss: 0.0014
# Epoch 36/50
# 301/301 [==============================] - 2s 6ms/step - loss: 0.0015
# Epoch 37/50
# 301/301 [==============================] - 2s 6ms/step - loss: 0.0014
# Epoch 38/50
# 301/301 [==============================] - 2s 6ms/step - loss: 0.0014
# Epoch 39/50
# 301/301 [==============================] - 2s 6ms/step - loss: 0.0014
# Epoch 40/50
# 301/301 [==============================] - 2s 7ms/step - loss: 0.0015
# Epoch 41/50
# 301/301 [==============================] - 2s 6ms/step - loss: 0.0014
# Epoch 42/50
# 301/301 [==============================] - 2s 6ms/step - loss: 0.0015
# Epoch 43/50
# 301/301 [==============================] - 5s 15ms/step - loss: 0.0013
# Epoch 44/50
# 301/301 [==============================] - 3s 10ms/step - loss: 0.0013
# Epoch 45/50
# 301/301 [==============================] - 2s 8ms/step - loss: 0.0015
# Epoch 46/50
# 301/301 [==============================] - 2s 7ms/step - loss: 0.0018
# Epoch 47/50
# 301/301 [==============================] - 5s 16ms/step - loss: 0.0013
# Epoch 48/50
# 301/301 [==============================] - 3s 11ms/step - loss: 0.0016
# Epoch 49/50
# 301/301 [==============================] - 4s 15ms/step - loss: 0.0013
# Epoch 50/50
# 301/301 [==============================] - 4s 12ms/step - loss: 0.0015

# %%
model.history.history.keys()
# Out:
# dict_keys(['loss'])

# %%
loss_per_epoch = model.history.history['loss']
plt.plot(range(len(loss_per_epoch)),loss_per_epoch)

# %% [markdown]
# ## Evaluate_The_Data

# %%
first_eval_batch = scaled_train[-12:]

# %%
first_eval_batch
# Out:
# array([[0.63432772],
#        [0.80776135],
#        [0.72313873],
#        [0.89870929],
#        [1.        ],
#        [0.71672793],
#        [0.88648602],
#        [0.75869732],
#        [0.82742115],
#        [0.87443371],
#        [0.96025301],
#        [0.5584238 ]])

# %%
first_eval_batch = first_eval_batch.reshape((1, n_input, n_features))

# %%
model.predict(first_eval_batch)
# Out:
# array([[0.7279355]], dtype=float32)

# %%
scaled_test[0]
# Out:
# array([0.63116506])

# %%
test_predictions = []

first_eval_batch = scaled_train[-n_input:]
current_batch = first_eval_batch.reshape((1, n_input, n_features))

# %%
current_batch.shape
# Out:
# (1, 12, 1)

# %%
current_batch
# Out:
# array([[[0.63432772],
#         [0.80776135],
#         [0.72313873],
#         [0.89870929],
#         [1.        ],
#         [0.71672793],
#         [0.88648602],
#         [0.75869732],
#         [0.82742115],
#         [0.87443371],
#         [0.96025301],
#         [0.5584238 ]]])

# %%
np.append(current_batch[:,1:,:],[[[99]]],axis=1)
# Out:
# array([[[ 0.80776135],
#         [ 0.72313873],
#         [ 0.89870929],
#         [ 1.        ],
#         [ 0.71672793],
#         [ 0.88648602],
#         [ 0.75869732],
#         [ 0.82742115],
#         [ 0.87443371],
#         [ 0.96025301],
#         [ 0.5584238 ],
#         [99.        ]]])

# %% [markdown]
# ### NOTE: PAY CLOSE ATTENTION HERE TO WHAT IS BEING OUTPUTED AND IN WHAT DIMENSIONS. ADD YOUR OWN PRINT() STATEMENTS TO SEE WHAT IS TRULY GOING ON!!

# %%
test_predictions = []

first_eval_batch = scaled_train[-n_input:]
current_batch = first_eval_batch.reshape((1, n_input, n_features))

for i in range(len(test)):
    
    # get prediction 1 time stamp ahead ([0] is for grabbing just the number instead of [array])
    current_pred = model.predict(current_batch)[0]
    
    # store prediction
    test_predictions.append(current_pred) 
    
    # update batch to now include prediction and drop first value
    current_batch = np.append(current_batch[:,1:,:],[[current_pred]],axis=1)

# %%
test_predictions
# Out:
# [array([0.7279355], dtype=float32),
#  array([0.8544754], dtype=float32),
#  array([0.800374], dtype=float32),
#  array([0.9748069], dtype=float32),
#  array([1.0586782], dtype=float32),
#  array([0.7876338], dtype=float32),
#  array([0.96875894], dtype=float32),
#  array([0.8064356], dtype=float32),
#  array([0.90061766], dtype=float32),
#  array([0.93332756], dtype=float32),
#  array([1.0314131], dtype=float32),
#  array([0.6171429], dtype=float32)]

# %%
scaled_test
# Out:
# array([[0.63116506],
#        [0.82502778],
#        [0.75972305],
#        [0.94939738],
#        [0.98743482],
#        [0.82135225],
#        [0.95956919],
#        [0.80049577],
#        [0.93025045],
#        [0.95247457],
#        [1.0661595 ],
#        [0.65706471]])

# %% [markdown]
# ## Inverse_Trasformation_And_Compare

# %%
true_predictions = scaler.inverse_transform(test_predictions)

# %%
true_predictions
# Out:
# array([[11547.11733252],
#        [13027.50745881],
#        [12394.57509214],
#        [14435.26597917],
#        [15416.47567892],
#        [12245.5275532 ],
#        [14364.51084721],
#        [12465.48990917],
#        [13567.32599372],
#        [13949.99907362],
#        [15097.50160313],
#        [10250.95497108]])

# %%
test
# Out:
#             Sales
# DATE
# 2018-02-01  10415
# 2018-03-01  12683
# 2018-04-01  11919
# 2018-05-01  14138
# 2018-06-01  14583
# 2018-07-01  12640
# 2018-08-01  14257
# 2018-09-01  12396
# 2018-10-01  13914
# 2018-11-01  14174
# 2018-12-01  15504
# 2019-01-01  10718

# %%
# IGNORE WARNINGS
test['Predictions'] = true_predictions
# Out:
# C:\Users\ssc\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
test
# Out:
#             Sales   Predictions
# DATE
# 2018-02-01  10415  11547.117333
# 2018-03-01  12683  13027.507459
# 2018-04-01  11919  12394.575092
# 2018-05-01  14138  14435.265979
# 2018-06-01  14583  15416.475679
# 2018-07-01  12640  12245.527553
# 2018-08-01  14257  14364.510847
# 2018-09-01  12396  12465.489909
# 2018-10-01  13914  13567.325994
# 2018-11-01  14174  13949.999074
# 2018-12-01  15504  15097.501603
# 2019-01-01  10718  10250.954971

# %%
test.plot(figsize=(12,8))

# %% [markdown]
# ## Saving and Loading Models

# %%
model.save('my_rnn_cool_model.h5')

# %% [markdown]
# ## load_a_model

# %%
from keras.models import load_model
new_model = load_model('my_rnn_model.h5')

# %%
new_model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_1 (LSTM)                (None, 100)               40800
# _________________________________________________________________
# dense_1 (Dense)              (None, 1)                 101
# =================================================================
# Total params: 40,901
# Trainable params: 40,901
# Non-trainable params: 0
# _________________________________________________________________
